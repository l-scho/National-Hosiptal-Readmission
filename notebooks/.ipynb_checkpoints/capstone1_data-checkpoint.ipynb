# %% [markdown]
# # Initial Import of Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import beta
import numpy as np
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv('../data/Hospital_Readmissions_Reduction_Program.csv', sep=';')

# %%
df.head(50)
# Out:
#                             Facility Name  Facility ID State  \
# 0        SOUTHEAST ALABAMA MEDICAL CENTER        10001    AL
# 1        SOUTHEAST ALABAMA MEDICAL CENTER        10001    AL
# 2        SOUTHEAST ALABAMA MEDICAL CENTER        10001    AL
# 3        SOUTHEAST ALABAMA MEDICAL CENTER        10001    AL
# 4        SOUTHEAST ALABAMA MEDICAL CENTER        10001    AL
# 5        SOUTHEAST ALABAMA MEDICAL CENTER        10001    AL
# 6   MARSHALL MEDICAL CENTERS SOUTH CAMPUS        10005    AL
# 7   MARSHALL MEDICAL CENTERS SOUTH CAMPUS        10005    AL
# 8   MARSHALL MEDICAL CENTERS SOUTH CAMPUS        10005    AL
# 9   MARSHALL MEDICAL CENTERS SOUTH CAMPUS        10005    AL
# 10  MARSHALL MEDICAL CENTERS SOUTH CAMPUS        10005    AL
# 11  MARSHALL MEDICAL CENTERS SOUTH CAMPUS        10005    AL
# 12           NORTH ALABAMA MEDICAL CENTER        10006    AL
# 13           NORTH ALABAMA MEDICAL CENTER        10006    AL
# 14           NORTH ALABAMA MEDICAL CENTER        10006    AL
# 15           NORTH ALABAMA MEDICAL CENTER        10006    AL
# 16           NORTH ALABAMA MEDICAL CENTER        10006    AL
# 17           NORTH ALABAMA MEDICAL CENTER        10006    AL
# 18               MIZELL MEMORIAL HOSPITAL        10007    AL
# 19               MIZELL MEMORIAL HOSPITAL        10007    AL
# 20               MIZELL MEMORIAL HOSPITAL        10007    AL
# 21               MIZELL MEMORIAL HOSPITAL        10007    AL
# 22               MIZELL MEMORIAL HOSPITAL        10007    AL
# 23               MIZELL MEMORIAL HOSPITAL        10007    AL
# 24            CRENSHAW COMMUNITY HOSPITAL        10008    AL
# 25            CRENSHAW COMMUNITY HOSPITAL        10008    AL
# 26            CRENSHAW COMMUNITY HOSPITAL        10008    AL
# 27            CRENSHAW COMMUNITY HOSPITAL        10008    AL
# 28            CRENSHAW COMMUNITY HOSPITAL        10008    AL
# 29            CRENSHAW COMMUNITY HOSPITAL        10008    AL
# 30                      ST VINCENT'S EAST        10011    AL
# 31                      ST VINCENT'S EAST        10011    AL
# 32                      ST VINCENT'S EAST        10011    AL
# 33                      ST VINCENT'S EAST        10011    AL
# 34                      ST VINCENT'S EAST        10011    AL
# 35                      ST VINCENT'S EAST        10011    AL
# 36         DEKALB REGIONAL MEDICAL CENTER        10012    AL
# 37         DEKALB REGIONAL MEDICAL CENTER        10012    AL
# 38         DEKALB REGIONAL MEDICAL CENTER        10012    AL
# 39         DEKALB REGIONAL MEDICAL CENTER        10012    AL
# 40         DEKALB REGIONAL MEDICAL CENTER        10012    AL
# 41         DEKALB REGIONAL MEDICAL CENTER        10012    AL
# 42          SHELBY BAPTIST MEDICAL CENTER        10016    AL
# 43          SHELBY BAPTIST MEDICAL CENTER        10016    AL
# 44          SHELBY BAPTIST MEDICAL CENTER        10016    AL
# 45          SHELBY BAPTIST MEDICAL CENTER        10016    AL
# 46          SHELBY BAPTIST MEDICAL CENTER        10016    AL
# 47          SHELBY BAPTIST MEDICAL CENTER        10016    AL
# 48    UAB CALLAHAN EYE HOSPITAL AUTHORITY        10018    AL
# 49    UAB CALLAHAN EYE HOSPITAL AUTHORITY        10018    AL
#
#               Measure Name  Number of Discharges  Footnote  \
# 0        READM-30-AMI-HRRP                 742.0       NaN
# 1       READM-30-CABG-HRRP                 279.0       NaN
# 2       READM-30-COPD-HRRP                 495.0       NaN
# 3         READM-30-HF-HRRP                1114.0       NaN
# 4   READM-30-HIP-KNEE-HRRP                 301.0       NaN
# 5         READM-30-PN-HRRP                 605.0       NaN
# 6        READM-30-AMI-HRRP                   NaN       NaN
# 7       READM-30-CABG-HRRP                   NaN       5.0
# 8       READM-30-COPD-HRRP                 636.0       NaN
# 9         READM-30-HF-HRRP                 341.0       NaN
# 10  READM-30-HIP-KNEE-HRRP                 257.0       NaN
# 11        READM-30-PN-HRRP                 697.0       NaN
# 12       READM-30-AMI-HRRP                 458.0       NaN
# 13      READM-30-CABG-HRRP                 136.0       NaN
# 14      READM-30-COPD-HRRP                 632.0       NaN
# 15        READM-30-HF-HRRP                 793.0       NaN
# 16  READM-30-HIP-KNEE-HRRP                 399.0       NaN
# 17        READM-30-PN-HRRP                 837.0       NaN
# 18       READM-30-AMI-HRRP                   NaN       1.0
# 19      READM-30-CABG-HRRP                   NaN       5.0
# 20      READM-30-COPD-HRRP                 140.0       NaN
# 21        READM-30-HF-HRRP                  79.0       NaN
# 22  READM-30-HIP-KNEE-HRRP                   NaN       NaN
# 23        READM-30-PN-HRRP                 211.0       NaN
# 24       READM-30-AMI-HRRP                   NaN       1.0
# 25      READM-30-CABG-HRRP                   NaN       5.0
# 26      READM-30-COPD-HRRP                   NaN       NaN
# 27        READM-30-HF-HRRP                   NaN       1.0
# 28  READM-30-HIP-KNEE-HRRP                   NaN       5.0
# 29        READM-30-PN-HRRP                   NaN       NaN
# 30       READM-30-AMI-HRRP                 165.0       NaN
# 31      READM-30-CABG-HRRP                  99.0       NaN
# 32      READM-30-COPD-HRRP                 308.0       NaN
# 33        READM-30-HF-HRRP                 449.0       NaN
# 34  READM-30-HIP-KNEE-HRRP                   NaN       NaN
# 35        READM-30-PN-HRRP                 421.0       NaN
# 36       READM-30-AMI-HRRP                  87.0       NaN
# 37      READM-30-CABG-HRRP                   NaN       5.0
# 38      READM-30-COPD-HRRP                 196.0       NaN
# 39        READM-30-HF-HRRP                 159.0       NaN
# 40  READM-30-HIP-KNEE-HRRP                   NaN       1.0
# 41        READM-30-PN-HRRP                 356.0       NaN
# 42       READM-30-AMI-HRRP                 210.0       NaN
# 43      READM-30-CABG-HRRP                   NaN       NaN
# 44      READM-30-COPD-HRRP                 238.0       NaN
# 45        READM-30-HF-HRRP                 384.0       NaN
# 46  READM-30-HIP-KNEE-HRRP                   NaN       NaN
# 47        READM-30-PN-HRRP                 377.0       NaN
# 48       READM-30-AMI-HRRP                   NaN       5.0
# 49      READM-30-CABG-HRRP                   NaN       5.0
#
#     Excess Readmission Ratio  Predicted Readmission Rate  \
# 0                     1.0446                     15.2935
# 1                     1.2361                     14.5943
# 2                     1.0249                     18.6162
# 3                     1.0453                     22.3772
# 4                     1.1787                      5.5863
# 5                     1.0049                     16.8059
# 6                     0.9255                     14.1024
# 7                        NaN                         NaN
# 8                     0.9028                     16.1179
# 9                     0.9911                     20.3917
# 10                    1.0232                      4.8877
# 11                    0.9833                     15.0773
# 12                    0.9673                     13.5122
# 13                    1.0096                     12.3254
# 14                    1.0018                     17.8584
# 15                    0.9469                     19.4539
# 16                    1.1841                      4.9578
# 17                    0.9827                     15.5479
# 18                       NaN                         NaN
# 19                       NaN                         NaN
# 20                    1.0361                     18.8096
# 21                    1.0744                     19.9189
# 22                    1.1268                      5.4144
# 23                    1.0590                     15.3122
# 24                       NaN                         NaN
# 25                       NaN                         NaN
# 26                    0.9728                     16.2425
# 27                       NaN                         NaN
# 28                       NaN                         NaN
# 29                    0.9610                     13.3078
# 30                    0.9533                     13.1426
# 31                    1.0967                     15.7703
# 32                    0.9219                     17.9044
# 33                    1.0427                     22.3671
# 34                    1.0344                      5.1935
# 35                    1.0048                     16.5520
# 36                    1.0053                     13.4547
# 37                       NaN                         NaN
# 38                    1.0220                     17.0367
# 39                    1.0326                     20.1724
# 40                       NaN                         NaN
# 41                    0.9782                     14.7245
# 42                    0.9327                     13.3153
# 43                    0.8833                     10.6747
# 44                    1.0394                     18.9437
# 45                    0.9552                     20.7808
# 46                    1.0222                      4.7148
# 47                    0.9819                     15.7011
# 48                       NaN                         NaN
# 49                       NaN                         NaN
#
#     Expected Readmission Rate Number of Readmissions  Start Date    End Date
# 0                     14.6404                    116  07/01/2015  06/30/2018
# 1                     11.8065                     46  07/01/2015  06/30/2018
# 2                     18.1637                     94  07/01/2015  06/30/2018
# 3                     21.4082                    252  07/01/2015  06/30/2018
# 4                      4.7392                     20  07/01/2015  06/30/2018
# 5                     16.7237                    102  07/01/2015  06/30/2018
# 6                     15.2379      Too Few to Report  07/01/2015  06/30/2018
# 7                         NaN                    NaN  07/01/2015  06/30/2018
# 8                     17.8526                     95  07/01/2015  06/30/2018
# 9                     20.5744                     69  07/01/2015  06/30/2018
# 10                     4.7767                     13  07/01/2015  06/30/2018
# 11                    15.3333                    104  07/01/2015  06/30/2018
# 12                    13.9685                     60  07/01/2015  06/30/2018
# 13                    12.2079                     17  07/01/2015  06/30/2018
# 14                    17.8263                    113  07/01/2015  06/30/2018
# 15                    20.5458                    151  07/01/2015  06/30/2018
# 16                     4.1869                     23  07/01/2015  06/30/2018
# 17                    15.8209                    129  07/01/2015  06/30/2018
# 18                        NaN                    NaN  07/01/2015  06/30/2018
# 19                        NaN                    NaN  07/01/2015  06/30/2018
# 20                    18.1544                     29  07/01/2015  06/30/2018
# 21                    18.5387                     20  07/01/2015  06/30/2018
# 22                     4.8053      Too Few to Report  07/01/2015  06/30/2018
# 23                    14.4590                     36  07/01/2015  06/30/2018
# 24                        NaN                    NaN  07/01/2015  06/30/2018
# 25                        NaN                    NaN  07/01/2015  06/30/2018
# 26                    16.6962      Too Few to Report  07/01/2015  06/30/2018
# 27                        NaN                    NaN  07/01/2015  06/30/2018
# 28                        NaN                    NaN  07/01/2015  06/30/2018
# 29                    13.8483      Too Few to Report  07/01/2015  06/30/2018
# 30                    13.7859                     19  07/01/2015  06/30/2018
# 31                    14.3802                     18  07/01/2015  06/30/2018
# 32                    19.4219                     49  07/01/2015  06/30/2018
# 33                    21.4507                    103  07/01/2015  06/30/2018
# 34                     5.0208      Too Few to Report  07/01/2015  06/30/2018
# 35                    16.4729                     70  07/01/2015  06/30/2018
# 36                    13.3845                     12  07/01/2015  06/30/2018
# 37                        NaN                    NaN  07/01/2015  06/30/2018
# 38                    16.6702                     35  07/01/2015  06/30/2018
# 39                    19.5349                     34  07/01/2015  06/30/2018
# 40                        NaN                    NaN  07/01/2015  06/30/2018
# 41                    15.0527                     51  07/01/2015  06/30/2018
# 42                    14.2755                     24  07/01/2015  06/30/2018
# 43                    12.0850      Too Few to Report  07/01/2015  06/30/2018
# 44                    18.2263                     48  07/01/2015  06/30/2018
# 45                    21.7563                     77  07/01/2015  06/30/2018
# 46                     4.6123      Too Few to Report  07/01/2015  06/30/2018
# 47                    15.9903                     58  07/01/2015  06/30/2018
# 48                        NaN                    NaN  07/01/2015  06/30/2018
# 49                        NaN                    NaN  07/01/2015  06/30/2018

# %%
df.columns
# Out:
# Index(['Facility Name', 'Facility ID', 'State', 'Measure Name',
#        'Number of Discharges', 'Footnote', 'Excess Readmission Ratio',
#        'Predicted Readmission Rate', 'Expected Readmission Rate',
#        'Number of Readmissions', 'Start Date', 'End Date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19344 entries, 0 to 19343
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Facility Name               19344 non-null  object
#  1   Facility ID                 19344 non-null  int64
#  2   State                       19344 non-null  object
#  3   Measure Name                19344 non-null  object
#  4   Number of Discharges        11440 non-null  float64
#  5   Footnote                    5274 non-null   float64
#  6   Excess Readmission Ratio    14071 non-null  float64
#  7   Predicted Readmission Rate  14071 non-null  float64
#  8   Expected Readmission Rate   14071 non-null  float64
#  9   Number of Readmissions      14071 non-null  object
#  10  Start Date                  19344 non-null  object
#  11  End Date                    19344 non-null  object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 1.8+ MB

# %%
df.describe()
# Out:
#          Facility ID  Number of Discharges     Footnote  \
# count   19344.000000          11440.000000  5274.000000
# mean   262195.596154            393.304808     3.635950
# std    162257.586241            363.203205     1.981472
# min     10001.000000              0.000000     1.000000
# 25%    110110.500000            158.000000     1.000000
# 50%    250089.000000            290.000000     5.000000
# 75%    390117.500000            508.000000     5.000000
# max    670128.000000           9356.000000    23.000000
#
#        Excess Readmission Ratio  Predicted Readmission Rate  \
# count              14071.000000                14071.000000
# mean                   1.002507                   15.383346
# std                    0.089052                    5.959672
# min                    0.623000                    2.199400
# 25%                    0.950850                   13.285200
# 50%                    0.997800                   16.712700
# 75%                    1.049400                   19.559800
# max                    2.183200                   30.257900
#
#        Expected Readmission Rate
# count               14071.000000
# mean                   15.337661
# std                     5.778370
# min                     2.799700
# 25%                    13.540200
# 50%                    16.639300
# 75%                    19.647700
# max                    25.697100

# %% [markdown]
# # Data Cleaning

# %%
df['Number of Discharges'] = df['Number of Discharges'].fillna(0) #change NaN to 0

# %%
df['Number of Readmissions'] = df['Number of Readmissions'].fillna(0) #change NaN to 0

# %%
df['Number of Readmissions'] = df['Number of Readmissions'].apply(lambda x: 0 if x == 'Too Few to Report' else x)

# %%
df['Number of Readmissions'] = df['Number of Readmissions'].astype(int)

# %%
df['Number of Discharges'] = df['Number of Discharges'].astype(int)

# %%
df['Readmission Rate'] = df['Number of Readmissions'] / df['Number of Discharges']

# %%
df.head(5)
# Out:
#                       Facility Name  Facility ID State  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER        10001    AL
# 1  SOUTHEAST ALABAMA MEDICAL CENTER        10001    AL
# 2  SOUTHEAST ALABAMA MEDICAL CENTER        10001    AL
# 3  SOUTHEAST ALABAMA MEDICAL CENTER        10001    AL
# 4  SOUTHEAST ALABAMA MEDICAL CENTER        10001    AL
#
#              Measure Name  Number of Discharges  Footnote  \
# 0       READM-30-AMI-HRRP                   742       NaN
# 1      READM-30-CABG-HRRP                   279       NaN
# 2      READM-30-COPD-HRRP                   495       NaN
# 3        READM-30-HF-HRRP                  1114       NaN
# 4  READM-30-HIP-KNEE-HRRP                   301       NaN
#
#    Excess Readmission Ratio  Predicted Readmission Rate  \
# 0                    1.0446                     15.2935
# 1                    1.2361                     14.5943
# 2                    1.0249                     18.6162
# 3                    1.0453                     22.3772
# 4                    1.1787                      5.5863
#
#    Expected Readmission Rate  Number of Readmissions  Start Date    End Date  \
# 0                    14.6404                     116  07/01/2015  06/30/2018
# 1                    11.8065                      46  07/01/2015  06/30/2018
# 2                    18.1637                      94  07/01/2015  06/30/2018
# 3                    21.4082                     252  07/01/2015  06/30/2018
# 4                     4.7392                      20  07/01/2015  06/30/2018
#
#    Readmission Rate
# 0          0.156334
# 1          0.164875
# 2          0.189899
# 3          0.226212
# 4          0.066445

# %% [markdown]
# # Hypothesis Testing

# %%
grouped_by_state = df.groupby(['State']).sum()

# %%
grouped_by_state.head(5)
# Out:
#        Facility ID  Number of Discharges  Footnote  Excess Readmission Ratio  \
# State
# AK          960672                  4884      44.0                   36.4421
# AL         4899078                 88235     570.0                  328.5386
# AR        11057514                 62604     291.0                  199.2318
# AZ        11008212                 80832     420.0                  256.9807
# CA        89164008                316731    1623.0                 1221.1025
#
#        Predicted Readmission Rate  Expected Readmission Rate  \
# State
# AK                       522.5422                   541.4157
# AL                      5043.5981                  4980.0792
# AR                      2936.2502                  2868.1222
# AZ                      3695.5661                  3782.8751
# CA                     19582.7671                 19382.6728
#
#        Number of Readmissions  Readmission Rate
# State
# AK                        681          3.441625
# AL                      14128         42.740238
# AR                       9894         27.993832
# AZ                      10390         30.128955
# CA                      51765        171.311871

# %%
df_test = grouped_by_state.reset_index()
#df_test.head()

# %%
coastal = ['WA', 'CA', 'OR', 'TX', 'LA', 'FL', 'GA', 'SC', 'NC', 'VA', 'MD', 'DE', 'NJ', 'NY', 'CT', 'RI', 'MA', 'NH', 'ME']

# %%
coastal_df = df_test.loc[df_test['State'].isin(coastal), :] #variation A

# %%
non_coastal_df = df_test.loc[~df_test['State'].isin(coastal), :] #Variation B

# %%
#coastal_df.head(20)

# %%
#non_coastal_df.head(35)

# %%
prior_a = 1
prior_b = 1

# %%
#P(Var|n; c) = f(x; a + c; b + (n - c)) -> This is the posterior equation

# %%
varA_c = coastal_df['Number of Readmissions'].sum()

# %%
varA_n= coastal_df['Number of Discharges'].sum()

# %%
varB_c = non_coastal_df['Number of Readmissions'].sum()

# %%
varB_n = non_coastal_df['Number of Discharges'].sum()

# %%
#posterior parameters

# %%
varA_posteriora = prior_a + varA_c

# %%
varB_posteriora = prior_a + varB_c

# %%
varA_posteriorb = prior_b + (varA_n - varA_c)

# %%
varB_posteriorb = prior_b + (varB_n - varB_c)

# %%
#posterior probabilty distribution function

# %%
fig, ax = plt.subplots(figsize = (12,5))
x = np.linspace(0,1,10000)
for (a,b,s,label) in [(varA_posteriora+1, varA_posteriorb+1, "lightsalmon", "Coastal Readmission Rate"),
                      (varB_posteriora+1, varB_posteriorb+1, "indianred", "Non-Coastal Readmission Rate")]:
    ax.plot(x,
            stats.beta(a,b).pdf(x),
            s,
            label=label)
ax.legend(loc="upper right")
ax.set_xlabel("p")
ax.set_ylabel("pdf")
ax.set_xlim(0.151, .165)
ax.set_title("Probabilities of Readmission Rate for Coastal and Non-Coastal Hospitals")
plt.savefig('../images/prob-readmission.png')

# %%
#posterior PDF

# %%
#rvs_varA = stats.beta(varA_posteriora,varA_posteriorb).rvs(1000000000)

# %%
#rvs_varB = stats.beta(varB_posteriora,varB_posteriorb).rvs(1000000000)

# %%
#x = rvs_varA < rvs_varB

# %%
#np.mean(x)

# %%
#joint posterior

# %%
varA_posterior = beta.pdf(x, varA_posteriora, varA_posteriorb)
varB_posterior = beta.pdf(x, varB_posteriora, varB_posteriorb)
joint_posterior = np.zeros(shape = (100,100))

for i in range(100):
    for j in range(100):
        joint_posterior[i][j] = varA_posterior[i] * varB_posterior[j]

# %%
val_varA = np.random.beta(varA_posteriora, varA_posteriorb, 10000)
val_varB = np.random.beta(varB_posteriora, varB_posteriorb, 10000)


vals_both_var = np.vstack([val_varA, val_varB]).T

df_a = pd.DataFrame(vals_both_var, columns=['VarA', 'VarB'])
g = sns.jointplot(x = df_a.VarA, y=df_a.VarB, kind='kde', n_levels=15)
g.ax_joint.plot([0, 0.5], [0, 0.5])
plt.show()

# %%
#joint posterior

# %%
#plot posterior

# %%
#percent better

# %%
#loss

# %%
grouped_by_state_and_measure = df.groupby(['State', 'Measure Name']).sum()

# %%
df_test2 = grouped_by_state_and_measure.reset_index()

# %%
coastal_nomeasure_df = df_test2.loc[df_test2['State'].isin(coastal), :]
noncoastal_nomeasure_df = df_test2.loc[~df_test2['State'].isin(coastal), :]
coastal_AMI_df = coastal_nomeasure_df.loc[df_test2['Measure Name'] == 'READM-30-AMI-HRRP', :]
noncoastal_AMI_df = df_test2.loc[df_test2['Measure Name'] == 'READM-30-AMI-HRRP', :]

# %%
varA_c_AMI = coastal_AMI_df['Number of Readmissions'].sum() 
varA_n_AMI = coastal_AMI_df['Number of Discharges'].sum()
varB_c_AMI = noncoastal_AMI_df['Number of Readmissions'].sum()
varB_n_AMI = noncoastal_AMI_df['Number of Discharges'].sum()

varA_posteriora_AMI = prior_a + varA_c_AMI
varB_posteriora_AMI = prior_a + varB_c_AMI
varA_posteriorb_AMI = prior_b + (varA_n_AMI - varA_c_AMI)
varB_posteriorb_AMI = prior_b + (varB_n_AMI - varB_c_AMI)

# %%
fig, ax = plt.subplots(figsize = (12,5))
x = np.linspace(0,1,10000)
for (a,b,s,label) in [(varA_posteriora_AMI+1, varA_posteriorb_AMI+1, "lightsalmon", "Coastal Readmission Rate for AMI"),
                      (varB_posteriora_AMI+1, varB_posteriorb_AMI+1, "indianred", "Non-Coastal Readmission Rate for AMI")]:
    ax.plot(x,
            stats.beta(a,b).pdf(x),
            s,
            label=label)
ax.legend(loc="upper right")
ax.set_xlabel("p")
ax.set_ylabel("pdf")
ax.set_xlim(0.149, .165)
ax.set_title("Probabilities of AMI Readmission Rate for Coastal and Non-Coastal Hospitals")
plt.savefig('../images/prob-ami-readmission.png')

# %%
coastal_COPD_df = coastal_nomeasure_df.loc[df_test2['Measure Name'] == 'READM-30-COPD-HRRP', :]
noncoastal_COPD_df = df_test2.loc[df_test2['Measure Name'] == 'READM-30-COPD-HRRP', :]

# %%
varA_c_COPD = coastal_COPD_df['Number of Readmissions'].sum() 
varA_n_COPD = coastal_COPD_df['Number of Discharges'].sum()
varB_c_COPD = noncoastal_COPD_df['Number of Readmissions'].sum()
varB_n_COPD = noncoastal_COPD_df['Number of Discharges'].sum()

varA_posteriora_COPD = prior_a + varA_c_COPD
varB_posteriora_COPD = prior_a + varB_c_COPD
varA_posteriorb_COPD = prior_b + (varA_n_COPD - varA_c_COPD)
varB_posteriorb_COPD = prior_b + (varB_n_COPD - varB_c_COPD)

# %%
fig, ax = plt.subplots(figsize = (12,5))
x = np.linspace(0,1,10000)
for (a,b,s,label) in [(varA_posteriora_COPD+1, varA_posteriorb_COPD+1, "lightsalmon", "Coastal Readmission Rate for COPD"),
                      (varB_posteriora_COPD+1, varB_posteriorb_COPD+1, "indianred", "Non-Coastal Readmission Rate for COPD")]:
    ax.plot(x,
            stats.beta(a,b).pdf(x),
            s,
            label=label)
ax.legend(loc="upper right")
ax.set_xlabel("p")
ax.set_ylabel("pdf")
ax.set_xlim(0.19, 0.205)
ax.set_title("Probabilities of COPD Readmission Rate for Coastal and Non-Coastal Hospitals")
plt.savefig('../images/prob-copd-readmission.png')

# %%
coastal_CABG_df = coastal_nomeasure_df.loc[df_test2['Measure Name'] == 'READM-30-CABG-HRRP', :]
noncoastal_CABG_df = df_test2.loc[df_test2['Measure Name'] == 'READM-30-CABG-HRRP', :]

# %%
varA_c_CABG = coastal_CABG_df['Number of Readmissions'].sum() 
varA_n_CABG = coastal_CABG_df['Number of Discharges'].sum()
varB_c_CABG = noncoastal_CABG_df['Number of Readmissions'].sum()
varB_n_CABG = noncoastal_CABG_df['Number of Discharges'].sum()

varA_posteriora_CABG = prior_a + varA_c_CABG
varB_posteriora_CABG = prior_a + varB_c_CABG
varA_posteriorb_CABG = prior_b + (varA_n_CABG - varA_c_CABG)
varB_posteriorb_CABG = prior_b + (varB_n_CABG - varB_c_CABG)

# %%
fig, ax = plt.subplots(figsize = (12,5))
x = np.linspace(0,1,10000)
for (a,b,s,label) in [(varA_posteriora_CABG+1, varA_posteriorb_CABG+1, "lightsalmon", "Coastal Readmission Rate for CABG"),
                      (varB_posteriora_CABG+1, varB_posteriorb_CABG+1, "indianred", "Non-Coastal Readmission Rate for CABG")]:
    ax.plot(x,
            stats.beta(a,b).pdf(x),
            s,
            label=label)
ax.legend(loc="upper right")
ax.set_xlabel("p")
ax.set_ylabel("pdf")
ax.set_xlim(0.115, 0.145)
ax.set_title("Probabilities of CABG Readmission Rate for Coastal and Non-Coastal Hospitals")
plt.savefig('../images/prob-cabg-readmission.png')

# %%
coastal_HF_df = coastal_nomeasure_df.loc[df_test2['Measure Name'] == 'READM-30-HF-HRRP', :]
noncoastal_HF_df = df_test2.loc[df_test2['Measure Name'] == 'READM-30-HF-HRRP', :]

# %%
varA_c_HF = coastal_HF_df['Number of Readmissions'].sum() 
varA_n_HF = coastal_HF_df['Number of Discharges'].sum()
varB_c_HF = noncoastal_HF_df['Number of Readmissions'].sum()
varB_n_HF = noncoastal_HF_df['Number of Discharges'].sum()

varA_posteriora_HF = prior_a + varA_c_HF
varB_posteriora_HF = prior_a + varB_c_HF
varA_posteriorb_HF = prior_b + (varA_n_HF - varA_c_HF)
varB_posteriorb_HF = prior_b + (varB_n_HF - varB_c_HF)

# %%
fig, ax = plt.subplots(figsize = (12,5))
x = np.linspace(0,1,10000)
for (a,b,s,label) in [(varA_posteriora_HF+1, varA_posteriorb_HF+1, "lightsalmon", "Coastal Readmission Rate for HF"),
                      (varB_posteriora_HF+1, varB_posteriorb_HF+1, "indianred", "Non-Coastal Readmission Rate for HF")]:
    ax.plot(x,
            stats.beta(a,b).pdf(x),
            s,
            label=label)
ax.legend(loc="upper right")
ax.set_xlabel("p")
ax.set_ylabel("pdf")
ax.set_xlim(0.2075, 0.225)
ax.set_title("Probabilities of HF Readmission Rate for Coastal and Non-Coastal Hospitals")
plt.savefig('../images/prob-hf-readmission.png')

# %%
coastal_HIP_KNEE_df = coastal_nomeasure_df.loc[df_test2['Measure Name'] == 'READM-30-HIP-KNEE-HRRP', :]
noncoastal_HIP_KNEE_df = df_test2.loc[df_test2['Measure Name'] == 'READM-30-HIP-KNEE-HRRP', :]

# %%
varA_c_HIP_KNEE = coastal_HIP_KNEE_df['Number of Readmissions'].sum() 
varA_n_HIP_KNEE = coastal_HIP_KNEE_df['Number of Discharges'].sum()
varB_c_HIP_KNEE = noncoastal_HIP_KNEE_df['Number of Readmissions'].sum()
varB_n_HIP_KNEE = noncoastal_HIP_KNEE_df['Number of Discharges'].sum()

varA_posteriora_HIP_KNEE = prior_a + varA_c_HIP_KNEE
varB_posteriora_HIP_KNEE = prior_a + varB_c_HIP_KNEE
varA_posteriorb_HIP_KNEE = prior_b + (varA_n_HIP_KNEE - varA_c_HIP_KNEE)
varB_posteriorb_HIP_KNEE = prior_b + (varB_n_HIP_KNEE - varB_c_HIP_KNEE)

# %%
fig, ax = plt.subplots(figsize = (12,5))
x = np.linspace(0,1,10000)
for (a,b,s,label) in [(varA_posteriora_HIP_KNEE+1, varA_posteriorb_HIP_KNEE+1, "lightsalmon", "Coastal Readmission Rate for HIP-KNEE"),
                      (varB_posteriora_HIP_KNEE+1, varB_posteriorb_HIP_KNEE+1, "indianred", "Non-Coastal Readmission Rate for HIP-KNEE")]:
    ax.plot(x,
            stats.beta(a,b).pdf(x),
            s,
            label=label)
ax.legend(loc="upper right")
ax.set_xlabel("p")
ax.set_ylabel("pdf")
ax.set_xlim(0.036, 0.044)
ax.set_title("Probabilities of Hip/Knee Readmission Rate for Coastal and Non-Coastal Hospitals")
plt.savefig('../images/prob-hipknee-readmission.png')

# %%
coastal_PN_df = coastal_nomeasure_df.loc[df_test2['Measure Name'] == 'READM-30-PN-HRRP', :]
noncoastal_PN_df = df_test2.loc[df_test2['Measure Name'] == 'READM-30-PN-HRRP', :]

# %%
varA_c_PN = coastal_PN_df['Number of Readmissions'].sum() 
varA_n_PN = coastal_PN_df['Number of Discharges'].sum()
varB_c_PN = noncoastal_PN_df['Number of Readmissions'].sum()
varB_n_PN = noncoastal_PN_df['Number of Discharges'].sum()

varA_posteriora_PN = prior_a + varA_c_PN
varB_posteriora_PN = prior_a + varB_c_PN
varA_posteriorb_PN = prior_b + (varA_n_PN - varA_c_PN)
varB_posteriorb_PN = prior_b + (varB_n_PN - varB_c_PN)

# %%
fig, ax = plt.subplots(figsize = (12,5))
x = np.linspace(0,1,10000)
for (a,b,s,label) in [(varA_posteriora_PN+1, varA_posteriorb_PN+1, "lightsalmon", "Coastal Readmission Rate for PN"),
                      (varB_posteriora_PN+1, varB_posteriorb_PN+1, "indianred", "Non-Coastal Readmission Rate for PN")]:
    ax.plot(x,
            stats.beta(a,b).pdf(x),
            s,
            label=label)
ax.legend(loc="upper right")
ax.set_xlabel("p")
ax.set_ylabel("pdf")
ax.set_xlim(0.16, 0.175)
ax.set_title("Probabilities of PN Readmission Rate for Coastal and Non-Coastal Hospitals")
plt.savefig('../images/prob-pn-readmission.png')

# %% [markdown]
# # Visualizations

# %%
grouped_measure = df.groupby(['Measure Name']).sum()

# %%
grouped_measure.head(20)
# Out:
#                         Facility ID  Number of Discharges  Footnote  \
# Measure Name
# READM-30-AMI-HRRP         845318602                451012    2553.0
# READM-30-CABG-HRRP        845318602                105425   10563.0
# READM-30-COPD-HRRP        845318602                749287    1245.0
# READM-30-HF-HRRP          845318602               1129905    1263.0
# READM-30-HIP-KNEE-HRRP    845318602                832235    2495.0
# READM-30-PN-HRRP          845318602               1231543    1057.0
#
#                         Excess Readmission Ratio  Predicted Readmission Rate  \
# Measure Name
# READM-30-AMI-HRRP                      2055.9831                  32363.5230
# READM-30-CABG-HRRP                      995.1767                  12719.4873
# READM-30-COPD-HRRP                     2823.3156                  53748.3259
# READM-30-HF-HRRP                       2848.4037                  59993.6523
# READM-30-HIP-KNEE-HRRP                 2467.2966                  10439.5935
# READM-30-PN-HRRP                       2916.0987                  47194.4743
#
#                         Expected Readmission Rate  Number of Readmissions  \
# Measure Name
# READM-30-AMI-HRRP                      32253.4216                   68969
# READM-30-CABG-HRRP                     12682.3021                   13706
# READM-30-COPD-HRRP                     53662.3392                  147338
# READM-30-HF-HRRP                       59824.8248                  242078
# READM-30-HIP-KNEE-HRRP                 10352.2775                   33265
# READM-30-PN-HRRP                       47041.0630                  204867
#
#                         Readmission Rate
# Measure Name
# READM-30-AMI-HRRP             265.543623
# READM-30-CABG-HRRP             80.704918
# READM-30-COPD-HRRP            489.551537
# READM-30-HF-HRRP              568.679846
# READM-30-HIP-KNEE-HRRP         57.812966
# READM-30-PN-HRRP              445.382142

# %%
bars = ['AMI', 'HF', 'COPD', 'THA/TKA', 'CABG', 'PN']
readmission_rate = [(68969/451012), (242078/1129905), (147338/749287), (33265/832235), (13706/105425), (204867/1231543)]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(bars, readmission_rate)
ax.set_title('Readmission Rate for Varying Measures')
ax.set_xlabel('Condition')
ax.set_ylabel('Readmission Rate')
ax.get_children()[0].set_color('peachpuff')
ax.get_children()[1].set_color('lightsalmon')
ax.get_children()[2].set_color('coral')
ax.get_children()[3].set_color('salmon')
ax.get_children()[4].set_color('indianred')
ax.get_children()[5].set_color('brown')
plt.show()
plt.savefig('../images/readmission-for-varying-measures.png')

# %%
total_discharges = df['Number of Discharges'].sum()

# %%
total_discharges
# Out:
# 4499407

# %%
total_readmissions = df['Number of Readmissions'].sum()

# %%
total_readmissions
# Out:
# 710223

# %%
real_rate = total_readmissions/total_discharges

# %%
real_rate
# Out:
# 0.15784813420968585
